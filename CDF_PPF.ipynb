# %% [markdown]
# <a href="https://colab.research.google.com/github/2anoFIAP/DistribuicaoDATASCIENCE/blob/main/CDF_PPF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import norm
import numpy as np
#FEITO NA TABELA NA MAO NA RACA NA CONTA, SANGUE SUOR E LAGRIMAS
#Ex1: Resultado -> 9,18%
#Ex2: Resultado -> 10,56%
#Ex3: Resultado -> 58.99% de um atendimento durar entre 10 a 15 min
#Ex4: Resultado -> 5,48%
#Ex5: Resultado -> 4,46%
#Ex6: Resultado -> 4.01%
#Ex7: Resultado -> 74,92%
#Ex8: Resultado -> 10,56%
#Ex9: Resultado -> 10,56%
#Ex10: Resultado -> 73,3%
#Ex11: Resultado -> a faixa salarial e de 5.952
#Ex12: Resultado -> ter no minimo 85 pontos
#Ex13: Resultado -> o limite deve ser 322,3 C
#Ex14: Resultado -> 196,75 ms
#Ex15: Resultado -> 19,06 kgs

#FEITO NO CODIGO IGUAL UNS ENZO
'''media = 1200
dp = 150
limite_inferior = norm.ppf(0.10, media, dp)
limite_superior = norm.ppf(0.90, media, dp)
print(f"O intervalo dos 80% centrais de produtividade é:")
print(f"De {limite_inferior:.2f} até {limite_superior:.2f} peças.")'''
#Ex16: Resultado -> 1008 ate 1392 pecas em 80% dos dias

'''media = 13.4
dp = 0.5
tempo = norm.ppf(0.15, media, dp)
print(f"O tempo maximo para estar entre os 15%: {tempo:.2f}")'''
#Ex17: Resultado -> tempo maximo de 12,88

'''media = 2.00
dp = 0.08
p_inferior = norm.cdf(1.90, media, dp)
p_superior = 1 - norm.cdf(2.10, media, dp)
prob_fora = p_inferior + p_superior
print(f"Probabilidade de estar fora da especificação: {prob_fora:.4f}")
print(f"Ou seja, {prob_fora*100:.2f}% das chapas serão descartadas.")'''
#Ex18: Resultado -> 21.13% serao descartadas

'''media = 38
dp = 7
prob_maior = 1 - norm.cdf(50, media, dp)
print(f"Probabilidade de latência > 50 ms: {prob_maior*100:.2f}%")
tempo_limite = norm.ppf(0.95, media, dp)
print(f"O valor que delimita os 95% menores tempos é: {tempo_limite:.2f} ms")'''
#Ex19: Resutlado -> > 50 = 4,32% e 95% menores tempos = 49.51 ms

'''media = 52
dp = 6
limite_sup = norm.cdf(60, media, dp)
limite_inf = norm.cdf(48, media, dp)
prob_final = limite_sup - limite_inf
valor_rendimento = norm.ppf(0.25, media, dp)
print(f"Probabilidade entre 48 e 60 t/ha: {prob_final:.4f} ({prob_final*100:.2f}%)")
print(f"O rendimento que separa os 25% menores é: {valor_rendimento:.2f} t/ha")'''
#Ex20: Resultado -> 48 e 60 + 65,63% e os 25% menores = 48 toneladas

'''dados = [8, 11, 10, 9, 13, 12, 10, 11, 9, 14, 12, 11]
media = np.mean(dados)
dp = np.std(dados, ddof=1)
print(f"Média estimada: {media:.2f}")
print(f"Desvio padrão estimado: {dp:.2f}")
duracao = norm.cdf(10, media, dp)
limite_velocidade = norm.ppf(0.90, media, dp)
print(f"{duracao*100:.2f}% e {limite_velocidade:.2f}min")'''
#Ex21: Resultado -> media = 10,83 min, desvio padrao = 1,75 minutos, menos de 10 min = 31,69% e tempo dos 90% mais rapidos = 13,08 minutos

'''dados = [18.2,19.5,21.0,19.8,20.4,18.9,21.3,20.7,19.6]
media = np.mean(dados)
dp = np.std(dados, ddof=1)
print(f"Média estimada: {media:.2f}")
print(f"Desvio padrão estimado: {dp:.2f}")
peso = 1 - norm.cdf(21, media, dp)
p_30 = norm.ppf(0.30, media, dp)
print(f"Probabilidade de pesar mais de 21kg: {peso*100:.2f}%")
print(f"Peso correspondente ao percentil 30: {p_30:.2f} kg")'''
#Ex22: Resultado -> media 19.93 kg, desvio padrao 1.01 kg, mais de 21kg = 14.60% , percentil de 30 = 19.40Kg

'''dados = [56,61,67,72,75,70,64,69,73,68,66,71,74,62,65]
media = np.mean(dados)
dp = np.std(dados, ddof=1)
print(f"Média estimada: {media:.2f}")
print(f"Desvio padrão estimado: {dp:.2f}")
pontos = 1 - norm.cdf(70, media, dp)
piores = norm.ppf(0.10, media, dp)
print(f"{pontos*100:.2f}% essa e a prob de tirar mais pontos")
print(f"{piores:.2f} essa e anota dos 10% piores")'''
#Ex23: Resultado ->  media 67,53, desvio padrao 5,32, prob de tirar mais de 70 pontos = 32,13%, nota q separa dos 10% piores = 60.72 pontos

'''dados = [49.8,50.1,50.4,49.9,50.0,50.2,49.7,50.3,50.1,49.8,50.5,50.0]
media = np.mean(dados)
dp = np.std(dados, ddof=1)
print(f"Média estimada: {media:.2f}")
print(f"Desvio padrão estimado: {dp:.2f}")
peca = 1 - norm.cdf(50.3, media, dp)
valor_abaixo = norm.ppf(0.95, media, dp)
print(f"Probabilidade de diametro > 50.3 mm: {peca*100:.2f}%")
print(f"Valor que separa os 95% menores: {valor_abaixo:.2f} mm")'''
#Ex24: Resultado -> media 50.07, desvio padrao 0.25, diametro > 50.3mm = 17.52%, valor q separa dos 95% menores = 50.48mm

dados = [118,122,125,119,121,124,127,120,123,126,124,122,121,128]
media = np.mean(dados)
dp = np.std(dados, ddof=1)
print(f"Média estimada: {media:.2f}")
print(f"Desvio padrão estimado: {dp:.2f}")
consumo = 1 - norm.cdf(126, media, dp)
p_85 = norm.ppf(0.85, media, dp)
print(f"Probabilidade de consumo > 126: {consumo*100:.2f}%")
print(f"Valor que delimita o 85%: {p_85:.2f} kg")
#Ex25: Resultado -> media 122.86, desavio padrao 2.98, consumo > 126 = 14.61%, p_85 = 125,95 kWh
# Out:
# Média estimada: 122.86
# Desvio padrão estimado: 2.98
# Probabilidade de consumo > 126: 14.61%
# Valor que separa os 15% menores: 125.95 kg
